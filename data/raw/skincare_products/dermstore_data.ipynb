# %%
import pandas as pd
import json

# %%
df = pd.read_json("dermstore_data.json")

# %%
df.shape
# Out:
# (126, 24)

# %%
df.describe()
# Out:
#                 sku    product_id       price                  scraped_at
# count  1.260000e+02  1.260000e+02  126.000000                         126
# mean   1.318559e+07  1.318559e+07   78.088333  2024-02-11 11:17:24.230158
# min    1.030272e+07  1.030272e+07   11.000000         2024-02-11 11:15:28
# 25%    1.169451e+07  1.169451e+07   35.000000         2024-02-11 11:16:21
# 50%    1.291211e+07  1.291211e+07   52.500000         2024-02-11 11:17:18
# 75%    1.445992e+07  1.445992e+07   97.250000  2024-02-11 11:18:28.750000
# max    1.564870e+07  1.564870e+07  495.000000         2024-02-11 11:20:15
# std    1.513464e+06  1.513464e+06   77.597091                         NaN

# %%
df.head(5)
# Out:
#                                                  url  \
# 0  https://www.dermstore.com/p/exclusive-neostrat...
# 1  https://www.dermstore.com/p/pmd-pmd-clean-1-pi...
# 2  https://www.dermstore.com/p/neom-focus-the-min...
# 3  https://www.dermstore.com/p/briogeo-curl-chari...
# 4  https://www.dermstore.com/p/dermalogica-christ...
#
#                                                title        brand       sku  \
# 0         Exclusive NEOSTRATA Anti-Aging Firming Duo    Neostrata  13441438
# 1                                PMD Clean (1 piece)          PMD  12905594
# 2  NEOM Focus the Mind Essential Oil Blend 0.3 fl...         NEOM  12540840
# 3  Briogeo Curl Charisma™ Rice Amino + Avocado Hy...      Briogeo  11271963
# 4  Dermalogica Retinol Renewal Gift Set ($186 Value)  Dermalogica  15508780
#
#    product_id  price currency availability     condition rating_value  ...  \
# 0    13441438  188.0      USD   OutOfStock  NewCondition               ...
# ...

# %%
df["skin_type_and_concerns"].value_counts()
# Out:
# skin_type_and_concerns
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             73
# ...

# %%
df.shape
# Out:
# (126, 24)

# %%
df["category"]
# Out:
# 0      Brands / NEOSTRATA / Exclusive NEOSTRATA Anti-...
# 1                     Brands / PMD / PMD Clean (1 piece)
# 2      Brands / NEOM / NEOM Focus the Mind Essential ...
# 3      Brands / Briogeo / Briogeo Curl Charisma™ Rice...
# 4      Brands / Dermalogica / Dermalogica Retinol Ren...
#                              ...
# 121    Brands / RMS Beauty / RMS Beauty Kakadu Beauty...
# 122    Brands / Tarte Cosmetics / Tarte Foundcealer F...
# 123    Brands / Erborian / Erborian Skin Therapy Mult...
# 124    Brands / This Works / this works Perfect Hands...
# 125    Brands / KYPRIS / KYPRIS Clearing Serum Balanc...
# Name: category, Length: 126, dtype: str

# %%
# on supprime les colonnes qui ne serviront pas au modèle : sku, availability, uniq_id, scraped_at
df =
